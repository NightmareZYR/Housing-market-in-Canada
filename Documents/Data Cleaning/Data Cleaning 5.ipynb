# %% [markdown]
# ## NS

# %%
import pandas as pd

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NS_Drop_price_house.csv')
Point2_data['Province'] = 'NS' 
Point2_data['Region'] = 'Atlantic region' 
Point2_data.tail()
# Out:
#      Beds  Bath    Sqft Lot_Size         Type   Price  \
# 111     5     1  1796.0      NaN  Residential   80000
# 112     3     1   808.0     .335  Residential  249000
# 113     3     1  2412.0      NaN       Single  349000
# 114     3     2  1908.0     2.97  Residential  149000
# 115     3     1  1263.0     .247  Residential   82500
#
#                       Address Province           Region
# 111          277 Highway 217        NS  Atlantic region
# 112  1833 Eastern Shore Road        NS  Atlantic region
# 113            62 Smith Road        NS  Atlantic region
# 114               3501 Hwy 3        NS  Atlantic region
# 115       139 Payzant Street        NS  Atlantic region

# %%
#Point2_data.to_csv('Point2_data_NS_Drop_price_house.csv',index=False)

# %% [markdown]
# ### Prince Edward Island

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_PE_Drop_price_house.csv')
Point2_data['Province'] = 'PE' 
Point2_data['Region'] = 'Atlantic region' 
Point2_data.tail()
# Out:
#     Beds  Bath    Sqft Lot_Size         Type   Price               Address  \
# 16   2.0   1.0   900.0      NaN       Single  329000      55 Garwalt Lane
# 17   3.0   2.0  1786.0      NaN       Single  175000       480 Abney Road
# 18   3.0   1.0  1155.0      NaN       Single  247900          4131 RTE 17
# 19   4.0   2.0  2320.0     >0.3  Residential  399900     100 Scott Street
# 20   4.0   2.0     NaN     10.5  Residential  329000  2084 Valleyfield Rd
#
#    Province           Region
# 16       PE  Atlantic region
# 17       PE  Atlantic region
# 18       PE  Atlantic region
# 19       PE  Atlantic region
# 20       PE  Atlantic region

# %%
#Point2_data.to_csv('Point2_data_PE_Drop_price_house.csv',index=False)

# %% [markdown]
# ### New Brunswick

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NB_Drop_price_house.csv')
Point2_data['Province'] = 'NB' 
Point2_data['Region'] = 'Atlantic region' 
Point2_data.tail()
# Out:
#      Beds  Bath    Sqft Lot_Size    Type   Price  \
# 117   2.0   1.0     NaN      NaN  Single   55000
# 118   3.0   2.0     NaN     .201  Single  349000
# 119   1.0   NaN     NaN     1.71  Single   39900
# 120   2.0   1.0     NaN     3.22  Single   79000
# 121   3.0   1.0  1125.0      NaN  Single  129900
#
#                               Address Province           Region
# 117                         19 Rioux        NB  Atlantic region
# 118                210 Wright Street        NB  Atlantic region
# 119  Lot 93-2 Pokiok Settlement Road        NB  Atlantic region
# 120               848 Boul St Joseph        NB  Atlantic region
# 121            59 Schooner Cove Road        NB  Atlantic region

# %%
#Point2_data.to_csv('Point2_data_NB_Drop_price_house.csv',index=False)

# %% [markdown]
# ### Newfoundland and Labrador

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NL_Drop_price_house.csv')
Point2_data['Province'] = 'NL' 
Point2_data['Region'] = 'Atlantic region' 
Point2_data.tail()
# Out:
#      Beds  Bath    Sqft Lot_Size         Type   Price  \
# 100   4.0   5.0  3256.0      NaN       Single  525000
# 101   3.0   2.0  2704.0      NaN  Residential   99000
# 102   3.0   1.0   798.0      NaN  Residential   99900
# 103   3.0   1.0  2200.0      NaN  Residential   74900
# 104   2.0   1.0   990.0      NaN  Residential   69900
#
#                         Address Province           Region
# 100           170 Water Street        NL  Atlantic region
# 101              21 Park Drive        NL  Atlantic region
# 102  55 Southern Shore Highway        NL  Atlantic region
# 103         28 Spoon Cove Road        NL  Atlantic region
# 104               731 Main St.        NL  Atlantic region

# %%
#Point2_data.to_csv('Point2_data_NL_Drop_price_house.csv',index=False)

# %% [markdown]
# ### Quebec

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_QC_Drop_price_house.csv')
Point2_data['Province'] = 'QC' 
Point2_data['Region'] = 'Central Canada' 
Point2_data.tail()
# Out:
#     Beds  Bath      Sqft Lot_Size         Type   Price  \
# 49   3.0   2.0  266504.0     .553  Residential  585000
# 50   NaN   1.0       NaN     .107  Residential   55000
# 51   5.0   2.0       NaN     .254  Residential  115000
# 52   3.0   2.0  221209.0     .143  Residential  395000
# 53   2.0   2.0  448005.0     .289  Residential  699000
#
#                       Address Province          Region
# 49  1989 Ch. du Lac-Panneton        QC  Central Canada
# 50       2261 Ch. du Village        QC  Central Canada
# 51        41 Rue des Pins E.        QC  Central Canada
# 52        4191 Av. Larivière        QC  Central Canada
# 53     58 Ch. de la Sablière        QC  Central Canada

# %%
#Point2_data.to_csv('Point2_data_QC_Drop_price_house.csv',index=False)

# %% [markdown]
# ### Ontario

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_Drop_price_house.csv')
Point2_data['Province'] = 'ON' 
Point2_data['Region'] = 'Central Canada' 
Point2_data.tail()
# Out:
#      Beds  Bath    Sqft Lot_Size         Type    Price  \
# 298   3.0   5.0     NaN      NaN       Single  2999000
# 299   2.0   1.0   876.0      NaN  Residential   449000
# 300   3.0   1.0     NaN      NaN       Single   179000
# 301   2.0   1.0     NaN     >2.8       Single   549000
# 302   3.0   3.0  1800.0      NaN  Residential   849900
#
#                         Address Province          Region
# 298             39 QUARRY Road        ON  Central Canada
# 299         45 DRUMMOND Street        ON  Central Canada
# 300           1 Syenite Street        ON  Central Canada
# 301  1691 A BUCKSHOT LAKE Road        ON  Central Canada
# 302              87 Prior Lane        ON  Central Canada

# %%
#Point2_data.to_csv('Point2_data_ON_Drop_price_house.csv',index=False)

# %% [markdown]
# ### Manitoba

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_MB_Drop_price_house.csv')
Point2_data['Province'] = 'MB' 
Point2_data['Region'] = 'Prairie Provinces' 
Point2_data.tail()
# Out:
#     Beds  Bath    Sqft Lot_Size    Type   Price                 Address  \
# 27     3     2  1740.0      NaN  Single  299900     75 Hespeler Avenue
# 28     2     1  1057.0      NaN  Single   98000  204 MCMILLAN Street W
# 29     4     2  1980.0     ng>5  Single  199000   61 Kemnay Woods Lane
# 30     4     2  1424.0      NaN  Single  210000       581 Furby Street
# 31     2     1   520.0      NaN  Single   89900      131 Lisgar Avenue
#
#    Province             Region
# 27       MB  Prairie Provinces
# 28       MB  Prairie Provinces
# 29       MB  Prairie Provinces
# 30       MB  Prairie Provinces
# 31       MB  Prairie Provinces

# %%
#Point2_data.to_csv('Point2_data_MB_Drop_price_house.csv',index=False)

# %% [markdown]
# ### Saskatchewan

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_SK_Drop_price_house.csv')
Point2_data['Province'] = 'SK' 
Point2_data['Region'] = 'Prairie Provinces' 
Point2_data.tail()
# Out:
#      Beds  Bath    Sqft Lot_Size         Type   Price              Address  \
# 192   4.0   2.0   936.0     .344  Residential  155000    123 4th STREET W
# 193   3.0   1.0   734.0      NaN  Residential   29500  306 Dunning STREET
# 194   3.0   3.0  1170.0      NaN  Residential  325000      13 Ling STREET
# 195   2.0   1.0  1044.0     .183       Single   95000      5620 49 Avenue
# 196   4.0   1.0  1032.0     .321  Residential   89900      509 4th AVENUE
#
#     Province             Region
# 192       SK  Prairie Provinces
# 193       SK  Prairie Provinces
# 194       SK  Prairie Provinces
# 195       SK  Prairie Provinces
# 196       SK  Prairie Provinces

# %%
#Point2_data.to_csv('Point2_data_SK_Drop_price_house.csv',index=False)

# %% [markdown]
# ### Alberta

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_Drop_price_house.csv')
Point2_data['Province'] = 'AB' 
Point2_data['Region'] = 'Prairie Provinces' 
Point2_data.tail()
# Out:
#      Beds  Bath      Sqft Lot_Size    Type    Price  \
# 197   4.0   2.0    1468.0     9.88  Single  1224900
# 198   3.0   1.0    1072.0      NaN  Single    89900
# 199   4.0   2.0    1073.0     9.41    Farm  2400000
# 200   1.0   1.0  500526.0      NaN  Single    79900
# 201   4.0   5.0    4564.0     3.26  Single  2000000
#
#                        Address Province             Region
# 197     323023 Range Road 241        AB  Prairie Provinces
# 198              901 4 Avenue        AB  Prairie Provinces
# 199  28120 Township Road 381A        AB  Prairie Provinces
# 200                 50 ST 4908       AB  Prairie Provinces
# 201                7510 4 AVE        AB  Prairie Provinces

# %%
#Point2_data.to_csv('Point2_data_AB_Drop_price_house.csv',index=False)

# %% [markdown]
# ### British Columbia

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_BC_Drop_price_house.csv')
Point2_data['Province'] = 'BC' 
Point2_data['Region'] = 'West Coast' 
Point2_data.tail()
# Out:
#      Beds  Bath     Sqft Lot_Size         Type    Price  \
# 167   3.0   1.0   1420.0     >175       Single   575000
# 168   5.0   8.0   6802.0     .293       Single  5999000
# 169   5.0  10.0  14956.0     .016       Single  8999999
# 170   5.0   2.0   1994.0     .161       Single   198000
# 171   3.0   1.0   1968.0     3.31  Residential   899000
#
#                    Address Province      Region
# 167        8995 LOOS ROAD        BC  West Coast
# 168  1507 PINECREST DRIVE        BC  West Coast
# 169     133 Ravine Drive,        BC  West Coast
# 170     264 MURRAY Drive,        BC  West Coast
# 171       6446 Rimer Road        BC  West Coast

# %%
#Point2_data.to_csv('Point2_data_BC_Drop_price_house.csv',index=False)

# %% [markdown]
# ### Canada excluding North

# %%
Point2_data1= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NS_Drop_price_house.csv')
Point2_data2= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_PE_Drop_price_house.csv')
Point2_data3= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NB_Drop_price_house.csv')
Point2_data4= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NL_Drop_price_house.csv')
Point2_data5= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_QC_Drop_price_house.csv')
Point2_data6= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_Drop_price_house.csv')
Point2_data7= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_MB_Drop_price_house.csv')
Point2_data8= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_SK_Drop_price_house.csv')
Point2_data9= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_Drop_price_house.csv')
Point2_data10= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_BC_Drop_price_house.csv')

# %%
frames = [Point2_data1, Point2_data2, Point2_data3, Point2_data4, Point2_data5, Point2_data6, Point2_data7, Point2_data8, Point2_data9, Point2_data10]
Point2_data = pd.concat(frames)
Point2_data = Point2_data.reset_index()
Point2_data = Point2_data.drop(['index'],axis=1)
Point2_data.tail()
# Out:
#       Beds  Bath     Sqft Lot_Size         Type    Price  \
# 1319   3.0   1.0   1420.0     >175       Single   575000
# 1320   5.0   8.0   6802.0     .293       Single  5999000
# 1321   5.0  10.0  14956.0     .016       Single  8999999
# 1322   5.0   2.0   1994.0     .161       Single   198000
# 1323   3.0   1.0   1968.0     3.31  Residential   899000
#
#                     Address Province      Region
# 1319        8995 LOOS ROAD        BC  West Coast
# 1320  1507 PINECREST DRIVE        BC  West Coast
# 1321     133 Ravine Drive,        BC  West Coast
# 1322     264 MURRAY Drive,        BC  West Coast
# 1323       6446 Rimer Road        BC  West Coast

# %%
Point2_data.to_csv('Point2_data_Canada_house_DropPrice.csv',index=False)

# %%
Point2_data = Point2_data.drop(['Lot_Size','Type'],axis=1)

# %%
Point2_data.isnull().sum()
# Out:
# Beds         44
# Bath         47
# Sqft        396
# Price         0
# Address       0
# Province      0
# Region        0
# dtype: int64

# %%
Point2_data = Point2_data.dropna()

# %%
Point2_data = Point2_data.drop_duplicates()
Point2_data = Point2_data.reset_index()
Point2_data = Point2_data.drop(['index'],axis=1)

# %%
Point2_data.shape
# Out:
# (908, 7)

# %%
Point2_data.to_csv('Point2_data_Canada_house_DropPrice_NoNa.csv',index=False)
