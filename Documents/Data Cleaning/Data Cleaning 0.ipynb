# %% [markdown]
# Create a column called 'Province' and a column called 'Region' for each CSV file

# %%
import pandas as pd

# %% [markdown]
# ## Adding Province and Region

# %% [markdown]
# ### Nova Scotia

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NS_house.csv')
Point2_data['Province'] = 'NS' 
Point2_data['Region'] = 'Atlantic region' 
Point2_data.tail()
# Out:
#       Beds  Bath    Sqft Lot_Size         Type   Price  \
# 2096   4.0   1.0  2432.0      NaN       Single  179000
# 2097   NaN   NaN     NaN     .099  Residential  234900
# 2098   2.0   2.0  1082.0     .258  Residential  220000
# 2099   3.0   NaN  2125.0     >4.6  Residential  259000
# 2100   4.0   4.0  3109.0      NaN       Single  329000
#
#                          Address Province           Region
# 2096      1837 Sandy Point Road        NS  Atlantic region
# 2097  15100 Cabot Trail Highway        NS  Atlantic region
# 2098        800 Old Sambro Road        NS  Atlantic region
# 2099           470 Patrice Road        NS  Atlantic region
# 2100     288 South Foord Street        NS  Atlantic region

# %%
#Point2_data.to_csv('Point2_data_NS_house.csv',index=False)

# %% [markdown]
# ### Prince Edward Island

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_PE_house.csv')
Point2_data['Province'] = 'PE' 
Point2_data['Region'] = 'Atlantic region' 
Point2_data.tail()
# Out:
#      Beds  Bath    Sqft Lot_Size         Type   Price  \
# 601   4.0   3.0  2144.0      NaN  Residential  489000
# 602   3.0   3.0  1625.0     ng>2  Residential  599900
# 603   3.0   2.0  1800.0     >0.2  Residential  219900
# 604   4.0   2.0  1881.0     g>47         Farm  549000
# 605   NaN   NaN     NaN     0.84  Residential   49900
#
#                      Address Province           Region
# 601     45 Hillside Meadows        PE  Atlantic region
# 602   251 New Seabury Drive        PE  Atlantic region
# 603       2 Monaghan Street        PE  Atlantic region
# 604            1752 Rte 225        PE  Atlantic region
# 605  Lot 42 Sunset Crescent        PE  Atlantic region

# %%
#Point2_data.to_csv('Point2_data_PE_house.csv',index=False)

# %% [markdown]
# ### New Brunswick

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NB_house.csv')
Point2_data['Province'] = 'NB' 
Point2_data['Region'] = 'Atlantic region' 
Point2_data.tail()
# Out:
#       Beds  Bath    Sqft Lot_Size         Type     Price           Address  \
# 2367   3.0   3.0  2350.0      NaN       Single  229000.0  30 Queen Street
# 2368   2.0   2.0  1200.0     0.23  Residential  159900.0      121 Sanford
# 2369   3.0   3.0  1760.0     .658  Residential  349900.0  736 Amirault ST
# 2370   2.0   1.0     NaN      NaN       Single  184000.0   397 Shore Road
# 2371   4.0   5.0     NaN      NaN       Single  599900.0  561 King George
#
#      Province           Region
# 2367       NB  Atlantic region
# 2368       NB  Atlantic region
# 2369       NB  Atlantic region
# 2370       NB  Atlantic region
# 2371       NB  Atlantic region

# %%
#Point2_data.to_csv('Point2_data_NB_house.csv',index=False)

# %% [markdown]
# ### Newfoundland and Labrador

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NL_house.csv')
Point2_data['Province'] = 'NL' 
Point2_data['Region'] = 'Atlantic region' 
Point2_data.tail()
# Out:
#       Beds  Bath    Sqft Lot_Size         Type     Price  \
# 2462   2.0   1.0   800.0      NaN  Residential   69900.0
# 2463   3.0   1.0  2056.0      NaN  Residential  149900.0
# 2464   3.0   1.0  1000.0      NaN       Single   60000.0
# 2465   3.0   1.0  2480.0      NaN  Residential  299900.0
# 2466   4.0   2.0  1904.0      NaN  Residential  199500.0
#
#                          Address Province           Region
# 2462              9 Drakes Hill        NL  Atlantic region
# 2463          27 Gladstone Road        NL  Atlantic region
# 2464      13 Merasheen Crescent        NL  Atlantic region
# 2465     40 Mint Cove Pond Road        NL  Atlantic region
# 2466  5 Frecker Place Extension        NL  Atlantic region

# %%
#Point2_data.to_csv('Point2_data_NL_house.csv',index=False)

# %% [markdown]
# ### Quebec

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_QC_house.csv')
Point2_data['Province'] = 'QC' 
Point2_data['Region'] = 'Central Canada' 
Point2_data.tail()
# Out:
#       Beds  Bath    Sqft Lot_Size         Type      Price  \
# 2185   2.0   1.0     NaN      NaN  Residential   373000.0
# 2186   4.0   1.0     NaN     .609         Farm   900000.0
# 2187  11.0   1.0     NaN     .165  Residential   325000.0
# 2188   2.0   3.0  2374.0      NaN  Residential  2450000.0
# 2189   3.0   1.0     NaN     .119  Residential   238500.0
#
#                              Address Province          Region
# 2185                    Rue des Lys        QC  Central Canada
# 2186  3225 Boul. du Parc-Industriel        QC  Central Canada
# 2187                 259 Rue Roy S.        QC  Central Canada
# 2188   175 Rue de la Montagne #1401        QC  Central Canada
# 2189                513 Av. du Jade        QC  Central Canada

# %%
#Point2_data.to_csv('Point2_data_QC_house.csv',index=False)

# %% [markdown]
# ### Ontario

# %%
Point2_data1= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_house_under500000.csv')
Point2_data2= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_house_500kto700k.csv')
Point2_data3= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_house_700kto900k.csv')
Point2_data4= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_house_900kto1250k.csv')
Point2_data5= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_house_1250kto2000k.csv')
Point2_data6= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_house_2000kup.csv')

# %%
frames = [Point2_data1, Point2_data2, Point2_data3, Point2_data4, Point2_data5, Point2_data6]
Point2_data = pd.concat(frames)
Point2_data = Point2_data.reset_index()
Point2_data = Point2_data.drop(['index'],axis=1)
Point2_data['Province'] = 'ON' 
Point2_data['Region'] = 'Central Canada' 
Point2_data.tail()
# Out:
#        Beds  Bath    Sqft Lot_Size         Type         Price  \
# 13460   4.0   4.0     NaN      NaN  Residential   4290000 CAD
# 13461   2.0   1.0     NaN      NaN       Single  10000000 CAD
# 13462   6.0   4.0  3920.0      NaN  Residential   2200000 CAD
# 13463   5.0   9.0     NaN      NaN       Single   3500000 CAD
# 13464   5.0   3.0     NaN      NaN       Single   6175000 CAD
#
#                         Address Province          Region
# 13460          14 Oakcrest Ave        ON  Central Canada
# 13461      12864 INNIS LAKE DR        ON  Central Canada
# 13462  1089 North Service Road        ON  Central Canada
# 13463           1694 CENTRE RD        ON  Central Canada
# 13464      3650 EGLINTON AVE W        ON  Central Canada

# %%
#Point2_data.to_csv('Point2_data_ON_house.csv',index=False)

# %% [markdown]
# ### Manitoba

# %%
Point2_data= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_MB_house.csv')
Point2_data['Province'] = 'MB' 
Point2_data['Region'] = 'Prairie Provinces' 
Point2_data.tail()
# Out:
#       Beds  Bath    Sqft Lot_Size         Type        Price  \
# 1475   3.0   2.0  1600.0     ,038         Farm  3400000 CAD
# 1476   3.0   2.0  1271.0      NaN  Residential   359900 CAD
# 1477   3.0   2.0  1040.0     ,583         Farm  1800000 CAD
# 1478   7.0   6.0  3860.0     1.07       Single   720000 CAD
# 1479   4.0   2.0  1690.0      NaN  Residential   199900 CAD
#
#                                                 Address Province  \
# 1475  96062 Road 135N; Excellent 3,038 Acre Mixed Fa...       MB
# 1476                                   180 Park Grove         MB
# 1477   9,583 Acre Cattle Ranch - East of Rorketon, MB.        MB
# 1478                                171 Oak Bluff Road        MB
# 1479                                 276 Vivian Street        MB
#
#                  Region
# 1475  Prairie Provinces
# 1476  Prairie Provinces
# 1477  Prairie Provinces
# 1478  Prairie Provinces
# 1479  Prairie Provinces

# %%
#Point2_data.to_csv('Point2_data_MB_house.csv',index=False)

# %% [markdown]
# ### Saskatchewan

# %%
Point2_data1= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_SK_house_under200K.csv')
Point2_data2= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_SK_house_200K_400K.csv')
Point2_data3= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_SK_house_400Kup.csv')

# %%
frames = [Point2_data1, Point2_data2, Point2_data3]
Point2_data = pd.concat(frames)
Point2_data = Point2_data.reset_index()
Point2_data = Point2_data.drop(['index'],axis=1)
Point2_data['Province'] = 'SK' 
Point2_data['Region'] = 'Prairie Provinces' 
Point2_data.tail()
# Out:
#       Beds  Bath    Sqft Lot_Size         Type        Price  \
# 5611   4.0   3.0  2128.0     7.84  Residential   529000 CAD
# 5612   3.0   2.0  1293.0     .095  Residential   489800 CAD
# 5613   3.0   3.0  2450.0     0.08  Residential   549000 CAD
# 5614   4.0   3.0  1330.0     7.37  Residential   699800 CAD
# 5615   3.0   2.0  1600.0     4.61         Farm  2675000 CAD
#
#                                                 Address Province  \
# 5611                        Rural Address 8th STREET W        SK
# 5612                                 143 Fast CRESCENT        SK
# 5613                       Grandora Acreage - 40 acres        SK
# 5614  4100 11th Street West, Acreage Inside Saskatoo...       SK
# 5615  City of Saskatoon 11th Street West - 54.61 Acres        SK
#
#                  Region
# 5611  Prairie Provinces
# 5612  Prairie Provinces
# 5613  Prairie Provinces
# 5614  Prairie Provinces
# 5615  Prairie Provinces

# %%
#Point2_data.to_csv('Point2_data_SK_house.csv',index=False)

# %% [markdown]
# ### Alberta

# %%
Point2_data1= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_house_Under200K.csv')
Point2_data2= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_house_200K_300K.csv')
Point2_data3= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_house_300K_400K.csv')
Point2_data4= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_house_400K_500K.csv')
Point2_data5= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_house_500K_700K.csv')
Point2_data6= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_house_700Kup.csv')

# %%
frames = [Point2_data1, Point2_data2, Point2_data3, Point2_data4, Point2_data5, Point2_data6]
Point2_data = pd.concat(frames)
Point2_data = Point2_data.reset_index()
Point2_data = Point2_data.drop(['index'],axis=1)
Point2_data['Province'] = 'AB' 
Point2_data['Region'] = 'Prairie Provinces' 
Point2_data.tail()
# Out:
#        Beds  Bath    Sqft Lot_Size         Type        Price  \
# 12935   3.0   3.0  2488.0     01.1  Residential  1499900 CAD
# 12936   3.0   2.0  2952.0     1.61  Residential   929000 CAD
# 12937   6.0   4.0  4337.0     5.06       Single  1500000 CAD
# 12938   5.0   5.0  2407.0      NaN  Residential   759900 CAD
# 12939   3.0   4.0  1645.0     1.73  Residential   999000 CAD
#
#                           Address Province             Region
# 12935          28444 Highway 592        AB  Prairie Provinces
# 12936          8 Grasslands Road        AB  Prairie Provinces
# 12937  1200 Range Road  254 Road        AB  Prairie Provinces
# 12938       5205 59 Street Close        AB  Prairie Provinces
# 12939       353022 Range Road 43        AB  Prairie Provinces

# %%
#Point2_data.to_csv('Point2_data_AB_house.csv',index=False)

# %% [markdown]
# ### British Columbia

# %%
Point2_data1= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_BC_house_Under700K.csv')
Point2_data2= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_BC_house_700K_1500K.csv')
Point2_data3= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_BC_house_1500K_2000K.csv')
Point2_data4= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_BC_house_Beyond2000K.csv')

# %%
frames = [Point2_data1, Point2_data2, Point2_data3, Point2_data4]
Point2_data = pd.concat(frames)
Point2_data = Point2_data.reset_index()
Point2_data = Point2_data.drop(['index'],axis=1)
Point2_data['Province'] = 'BC' 
Point2_data['Region'] = 'West Coast' 
Point2_data.tail()
# Out:
#       Beds  Bath    Sqft Lot_Size    Type        Price  \
# 9201   4.0   3.0  3335.0     .172  Single  5550000 CAD
# 9202   4.0   3.0  2511.0     .239  Single  3024120 CAD
# 9203   4.0   4.0  4753.0     >1.2  Single  5180000 CAD
# 9204   5.0   8.0  6802.0     .293  Single  5999000 CAD
# 9205   NaN   4.0  3250.0     .171  Single  5000000 CAD
#
#                        Address Province      Region
# 9201        595 W 28TH AVENUE        BC  West Coast
# 9202       540 POIRIER STREET        BC  West Coast
# 9203         20395 74B AVENUE        BC  West Coast
# 9204     1507 PINECREST DRIVE        BC  West Coast
# 9205  25 W KING EDWARD AVENUE        BC  West Coast

# %%
#Point2_data.to_csv('Point2_data_BC_house.csv',index=False)

# %% [markdown]
# ### Canada excluding North

# %%
Point2_data1= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NS_house.csv')
Point2_data2= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_PE_house.csv')
Point2_data3= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NB_house.csv')
Point2_data4= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_NL_house.csv')
Point2_data5= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_QC_house.csv')
Point2_data6= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_ON_house.csv')
Point2_data7= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_MB_house.csv')
Point2_data8= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_SK_house.csv')
Point2_data9= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_AB_house.csv')
Point2_data10= pd.read_csv('/users/aeternus/Desktop/Housing-market-in-Canada/Point2_data_BC_house.csv')

# %%
frames = [Point2_data1, Point2_data2, Point2_data3, Point2_data4, Point2_data5, Point2_data6, Point2_data7, Point2_data8, Point2_data9, Point2_data10]
Point2_data = pd.concat(frames)
Point2_data = Point2_data.reset_index()
Point2_data = Point2_data.drop(['index'],axis=1)
Point2_data.tail()
# Out:
#        Beds  Bath    Sqft Lot_Size    Type        Price  \
# 52438   4.0   3.0  3335.0     .172  Single  5550000 CAD
# 52439   4.0   3.0  2511.0     .239  Single  3024120 CAD
# 52440   4.0   4.0  4753.0     >1.2  Single  5180000 CAD
# 52441   5.0   8.0  6802.0     .293  Single  5999000 CAD
# 52442   NaN   4.0  3250.0     .171  Single  5000000 CAD
#
#                         Address Province      Region
# 52438        595 W 28TH AVENUE        BC  West Coast
# 52439       540 POIRIER STREET        BC  West Coast
# 52440         20395 74B AVENUE        BC  West Coast
# 52441     1507 PINECREST DRIVE        BC  West Coast
# 52442  25 W KING EDWARD AVENUE        BC  West Coast

# %%
Point2_data.to_csv('Point2_data_Canada_house_ExcludingNorth.csv',index=False)
